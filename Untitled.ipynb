# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('2011.csv', encoding = 'cp1252')

# %%
data.head()
# Out:
#        Row Labels  CO2 emissions (metric tons per capita)  \
# 0     Afghanistan                                0.412017
# 1         Albania                                1.803715
# 2         Algeria                                3.291376
# 3  American Samoa                                     NaN
# 4         Andorra                                5.867130
#
#    Renewable electricity output (% of total electricity output)
# 0                                          82.487562
# 1                                          98.592221
# 2                                           0.980009
# 3                                           0.000000
# 4                                          86.513158

# %%
sns.jointplot(x='CO2 emissions (metric tons per capita)',y='Renewable electricity output (% of total electricity output)',data=data, kind='reg')

# %%
sns.heatmap(data.corr(),cmap='coolwarm',annot=True)

# %%
sns.lmplot(x='CO2 emissions (metric tons per capita)',y='Renewable electricity output (% of total electricity output)',data=data)

# %%
data.plot.bar(stacked=True)
fig.autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8472aedc9ac7> in <module>
#       1 data.plot.bar(stacked=True)
# ----> 2 fig.autofmt_xdate()
#
# NameError: name 'fig' is not defined
